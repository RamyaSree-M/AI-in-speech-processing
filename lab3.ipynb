# %% [markdown]
# # Lab 03

# %% [markdown]
# # Question: 01

# %%
#A1. Use librosa.effects.trim() to remove the silence parts of speech from beginning and end of your recorded signal.
# Listen to the new signal and perceptually compare the audio with original.

# %%
pip install librosa matplotlib pydub
# Out:
# Requirement already satisfied: librosa in c:\users\himas\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: matplotlib in c:\users\himas\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: pydub in c:\users\himas\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.7.3)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.21.6)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (4.9.0)
# Requirement already satisfied: msgpack>=1.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: pooch>=1.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\himas\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\himas\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\himas\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\himas\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\himas\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\himas\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\himas\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\himas\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\himas\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (61.2.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\himas\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (4.1.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\himas\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\himas\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\himas\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\himas\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\himas\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa soundfile
# Out:
# Requirement already satisfied: librosa in c:\users\himas\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: soundfile in c:\users\himas\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: joblib>=0.14 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: pooch>=1.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: msgpack>=1.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.21.6)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: numba>=0.51.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\himas\anaconda3\lib\site-packages (from librosa) (4.9.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\himas\anaconda3\lib\site-packages (from soundfile) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\himas\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: setuptools in c:\users\himas\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\himas\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\himas\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\himas\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\himas\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (4.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\himas\anaconda3\lib\site-packages (from packaging>=20.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\himas\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\himas\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import matplotlib.pyplot as plt

# Load the audio file
y, sr = librosa.load(r"C:\Users\himas\Downloads\sem6_learning\speechProcessing\lab3\voice_lab1.mp3")

# Display the original speech signal
plt.figure(figsize=(10, 4))
librosa.display.waveshow(y, sr=sr)
plt.title('Original Speech Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()


# Trim the silent parts from the beginning and end of the signal
y_trimmed,index= librosa.effects.trim(y)

# Display the trimmed speech signal
plt.figure(figsize=(10, 4))
librosa.display.waveshow(y_trimmed, sr=sr)
plt.title('Trimmed Speech Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # question: 2

# %%
# A2. Use librosa.effects.split() to split the recorded speech with detected silences.
# Play around with the top_db parameter and see the effects of split. 
# Listen to the generated signals and observe the split quality

# %%
import librosa
import sounddevice as sd

# Load the audio file
y, sr = librosa.load(r"C:\Users\himas\Downloads\sem6_learning\speechProcessing\lab3\voice_lab1.mp3")

# Split the speech signal into segments based on detected silences
segments = librosa.effects.split(y, top_db=20)  # Adjust top_db as needed

# Listen to each segment
for i, segment in enumerate(segments):
    start, end = segment
    segment_audio = y[start:end]

    print(f"Playing Segment {i+1}: Duration {len(segment_audio)/sr} seconds")
    sd.play(segment_audio, sr)
    sd.wait()
# Out:
# Playing Segment 1: Duration 0.626938775510204 seconds
# Playing Segment 2: Duration 0.18575963718820862 seconds
# Playing Segment 3: Duration 0.2089795918367347 seconds
# Playing Segment 4: Duration 0.13931972789115646 seconds
# Playing Segment 5: Duration 0.25541950113378686 seconds

# %% [markdown]
# # or

# %%
from IPython.display import Audio

# %%
y, sr = librosa.load(r"C:\Users\himas\Downloads\sem6_learning\speechProcessing\lab3\voice_lab1.mp3")

segments = librosa.effects.split(y, top_db=20)  # Adjust top_db as needed

for i, segment in enumerate(segments):
    start, end = segment
    segment_audio = y[start:end]

    print(f"Playing Segment {i+1}: Duration {len(segment_audio)/sr} seconds")
    display(Audio(segment_audio, rate=sr))
# Out:
# Playing Segment 1: Duration 0.626938775510204 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Playing Segment 2: Duration 0.18575963718820862 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Playing Segment 3: Duration 0.2089795918367347 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Playing Segment 4: Duration 0.13931972789115646 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Playing Segment 5: Duration 0.25541950113378686 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#A3. Use the IEEE paper reference available above for silence detection.
#Compare the results with the silence detection output from librosa package.
# ref: https://aseblr.sharepoint.com/sites/21AIE315-E/Class%20Materials/Forms/AllItems.aspx?id=%2Fsites%2F21AIE315%2DE%2FClass%20Materials%2FSilence%5FDetection%5Fand%5FRemoval%5FMethod%5FBased%5Fon%5Fthe%5FContinuous%5FAverage%5FEnergy%5Fof%5FSpeech%5FSignal%2Epdf&parent=%2Fsites%2F21AIE315%2DE%2FClass%20Materials&p=true&ga=1
