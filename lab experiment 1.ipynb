# %% [markdown]
# # LAB-01

# %% [markdown]
# # M RAMYA SREE

# %% [markdown]
# # QUESTION 01:

# %%
pip install librosa
# Out:
# ...
#   Using cached numpy-1.21.6-cp39-cp39-win_amd64.whl (14.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\himas\\anaconda3\\Lib\\site-packages\\~1mpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.3
#     Uninstalling numpy-1.26.3:
#       Successfully uninstalled numpy-1.26.3

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#  A1. Load the recorded speech file into your python workspace. 
#Once loaded, plot the graph for the speech signal. 
#You may use the below code from librosa as a reference

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
audiofile = r"C:\Users\himas\Downloads\sem6_learning\speechProcessing\voice_lab1.opus"

# Load the speech file
y, sr = librosa.load(audiofile)
print(y)
print(sr) # sampling rate of y
plt.figure(figsize=(16, 6))
librosa.display.waveshow(y)
plt.title('Speech Signal')
plt.xlabel('Time (ms)')
plt.ylabel('Amplitude')
plt.show()
# Out:
# [ 8.3307816e-07 -9.6827046e-07  1.4611317e-07 ...  5.9302739e-04
#   1.3415513e-03  7.3301856e-04]
# 22050

# %% [markdown]
# # Question: 02

# %%
# A2. Observe the length & magnitude range of the signal from the plot.
# Observing the plot, relate to the spoken words and silence between the words.

# %% [markdown]
# Length of the Signal (Time Axis):
#
# The length of the signal is the overall duration of the signal is from the beginning to the end of the plot.
#
# Magnitude Range (Amplitude Axis):
#
# The magnitude range is the difference between the highest and lowest points on the y-axis.
#
# Relation to Spoken Words and Silence:
#
# Spoken words are typically characterized by higher amplitudes, resulting in peaks in the plot.
# Silence or pauses between words are represented by regions of lower amplitude.

# %%
duration = len(y) / sr  # Duration in seconds
print(f"Duration of the audio: {duration:.2f} seconds")
print(f"Magnitude range: {y.min()} to {y.max()}")
# Out:
# Duration of the audio: 2.25 seconds
# Magnitude range: -0.6724227666854858 to 0.771579921245575

# %% [markdown]
# # Question: 03

# %%
# A3. Take a small segment of the signal and play it.

# %%
import IPython.display as ipd
audiofile = r"C:\Users\himas\Downloads\sem6_learning\speechProcessing\voice_lab1.opus"

# Load the speech file
y, sr = librosa.load(audiofile)

start_time1 = 1
end_time1 = 2  
segment1 = y[int(start_time1 * sr):int(end_time1 * sr)]

# Play the segment
ipd.Audio(segment1, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Question: 04

# %%
# A4. Play around with your recorded speech signal for various segments. 
# Understand the nature of the signal.
# Also observe with abruptly segmented speech,
# how the perception of that speech is  affected.

# %%
start_time2 = 0.1
end_time2 = 0.5 
segment2 = y[int(start_time2 * sr):int(end_time2 * sr)]

# Play the segment
ipd.Audio(segment2, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time3 = 1
end_time3 =  1.4
segment3 = y[int(start_time3 * sr):int(end_time3 * sr)]

# Play the segment
ipd.Audio(segment3, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np

# Fliping  the signal
flipped_segment4 = np.flip(segment3)

ipd.Audio(flipped_segment4, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# loss of context in each segmented signal, and the information is lost if the signal is flipped then it's not meaningful and information is mostly lost.
